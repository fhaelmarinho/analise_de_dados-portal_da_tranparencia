# %% [markdown]
# # LENDO OS DADOS

# %%
path = '/home/fhael/Documentos/Projetos/Asimov/AD/2024_Viagem.csv'

# %%
import pandas as pd

# %%
df_viagens = pd.read_csv(path, encoding="Windows-1252", sep=";")

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18831091                 000011/24
# 1                                  18831495                 000001/24
# 2                                  18831777                 000002/24
# 3                                  18831821                 000003/24
# 4                                  19177818              000001/24-1C
# ...                                     ...                       ...
# 773085                           2024001906             Sem informaçã
# 773086                           2024001911             Sem informaçã
# 773087                           2024001912             Sem informaçã
# 773088                           2024001946             Sem informaçã
# 773089                           2024001948             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
df_viagens[["Nome do órgão superior", "Nome órgão solicitante", "Valor diárias","Valor passagens" ]]
# Out:
#         Nome do órgão superior                       Nome órgão solicitante  \
# 0       Ministério da Educação                    Instituto Federal do Acre
# 1       Ministério da Educação  Fundação Universidade Federal de Uberlândia
# 2       Ministério da Educação  Fundação Universidade Federal de Uberlândia
# 3       Ministério da Educação  Fundação Universidade Federal de Uberlândia
# 4       Ministério da Educação            Fundação Universidade de Brasília
# ...                        ...                                          ...
# 773085          Sem informação                               Sem informação
# 773086          Sem informação                               Sem informação
# 773087          Sem informação                               Sem informação
# 773088          Sem informação                               Sem informação
# 773089          Sem informação                               Sem informação
#
#        Valor diárias Valor passagens
# ...
